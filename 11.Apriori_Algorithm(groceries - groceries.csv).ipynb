# %% [markdown]
# <h2>Apriori Algorithm in Machine Learning</h2>
# <h3><b>dataset :</b> groceries - groceries.csv</h3>
#
# The Apriori algorithm uses frequent itemsets to generate association rules, and it is designed to work on the databases that contain transactions. With the help of these association rule, it determines how strongly or how weakly two objects are connected. This algorithm uses a breadth-first search and Hash Tree to calculate the itemset associations efficiently. It is the iterative process for finding the frequent itemsets from the large dataset.
#
# This algorithm was given by the R. Agrawal and Srikant in the year 1994. It is mainly used for market basket analysis and helps to find those products that can be bought together. It can also be used in the healthcare field to find drug reactions for patients.
#
# Suppose there are the two transactions: A= {1,2,3,4,5}, and B= {2,3,7}, in these two transactions, 2 and 3 are the frequent itemsets.

# %% [markdown]
# Link : <a href="https://www.javatpoint.com/apriori-algorithm-in-machine-learning">Steps for Apriori Algorithm</a>

# %%
import pandas as pd

# %%
data = pd.read_csv('/Users/snehvora/Desktop/Machine Learning/groceries - groceries.csv')
data
# Out:
#       Item(s)               Item 1               Item 2            Item 3  \
# 0           4         citrus fruit  semi-finished bread         margarine
# 1           3       tropical fruit               yogurt            coffee
# 2           1           whole milk                  NaN               NaN
# 3           4            pip fruit               yogurt      cream cheese
# 4           4     other vegetables           whole milk    condensed milk
# ...       ...                  ...                  ...               ...
# 9830       17              sausage              chicken              beef
# 9831        1    cooking chocolate                  NaN               NaN
# 9832       10              chicken         citrus fruit  other vegetables
# 9833        4  semi-finished bread        bottled water              soda
# 9834        5              chicken       tropical fruit  other vegetables
#
#                         Item 4         Item 5          Item 6  \
# 0                  ready soups            NaN             NaN
# 1                          NaN            NaN             NaN
# 2                          NaN            NaN             NaN
# 3                 meat spreads            NaN             NaN
# 4     long life bakery product            NaN             NaN
# ...                        ...            ...             ...
# 9830            hamburger meat   citrus fruit          grapes
# 9831                       NaN            NaN             NaN
# 9832                    butter         yogurt  frozen dessert
# 9833              bottled beer            NaN             NaN
# 9834                   vinegar  shopping bags             NaN
#
#                Item 7      Item 8  Item 9  ... Item 23 Item 24 Item 25  \
# 0                 NaN         NaN     NaN  ...     NaN     NaN     NaN
# 1                 NaN         NaN     NaN  ...     NaN     NaN     NaN
# 2                 NaN         NaN     NaN  ...     NaN     NaN     NaN
# 3                 NaN         NaN     NaN  ...     NaN     NaN     NaN
# 4                 NaN         NaN     NaN  ...     NaN     NaN     NaN
# ...               ...         ...     ...  ...     ...     ...     ...
# 9830  root vegetables  whole milk  butter  ...     NaN     NaN     NaN
# 9831              NaN         NaN     NaN  ...     NaN     NaN     NaN
# 9832    domestic eggs  rolls/buns     rum  ...     NaN     NaN     NaN
# 9833              NaN         NaN     NaN  ...     NaN     NaN     NaN
# 9834              NaN         NaN     NaN  ...     NaN     NaN     NaN
#
#      Item 26 Item 27 Item 28 Item 29 Item 30 Item 31 Item 32
# 0        NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1        NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2        NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3        NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4        NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...      ...     ...     ...     ...     ...     ...     ...
# 9830     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 9831     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 9832     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 9833     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 9834     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# [9835 rows x 33 columns]

# %%
data = data.iloc[:,1:]
data.shape
# Out:
# (9835, 32)

# %%
transactions = []
for i in range(0,1000):  
    transactions.append([str(data.values[i,j]) for j in range(0, data.shape[1])])

# Each item in the record list will include items bought by a customer
transactions[0]
# Out:
# ['citrus fruit',
#  'semi-finished bread',
#  'margarine',
#  'ready soups',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan']

# %%
from apyori import apriori
association_rules = apriori(transactions=transactions, min_support=0.008, min_confidence=0.3, min_lift=3, min_length=2)

# %%
association_results = list(association_rules)
association_results
# Out:
# [RelationRecord(items=frozenset({'whipped/sour cream', 'berries'}), support=0.017, ordered_statistics=[OrderedStatistic(items_base=frozenset({'berries'}), items_add=frozenset({'whipped/sour cream'}), confidence=0.3617021276595745, lift=4.88786658999425)]),
#  RelationRecord(items=frozenset({'root vegetables', 'butter'}), support=0.017, ordered_statistics=[OrderedStatistic(items_base=frozenset({'butter'}), items_add=frozenset({'root vegetables'}), confidence=0.3695652173913044, lift=3.3596837944664033)]),
#  RelationRecord(items=frozenset({'candy', 'tropical fruit'}), support=0.009, ordered_statistics=[OrderedStatistic(items_base=frozenset({'candy'}), items_add=frozenset({'tropical fruit'}), confidence=0.35999999999999993, lift=3.7113402061855663)]),
#  RelationRecord(items=frozenset({'coffee', 'long life bakery product'}), support=0.008, ordered_statistics=[OrderedStatistic(items_base=frozenset({'long life bakery product'}), items_add=frozenset({'coffee'}), confidence=0.3076923076923077, lift=4.048582995951417)]),
#  RelationRecord(items=frozenset({'curd', 'sliced cheese'}), support=0.009, ordered_statistics=[OrderedStatistic(items_base=frozenset({'sliced cheese'}), items_add=frozenset({'curd'}), confidence=0.3214285714285714, lift=4.285714285714286)]),
#  RelationRecord(items=frozenset({'ham', 'whipped/sour cream'}), support=0.008, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ham'}), items_add=frozenset({'whipped/sour cream'}), confidence=0.38095238095238093, lift=5.148005148005148)]),
#  RelationRecord(items=frozenset({'hard cheese', 'tropical fruit'}), support=0.009, ordered_statistics=[OrderedStatistic(items_base=frozenset({'hard cheese'}), items_add=frozenset({'tropical fruit'}), confidence=0.37499999999999994, lift=3.865979381443298)]),
#  RelationRecord(items=frozenset({'newspapers', 'oil'}), support=0.01, ordered_statistics=[OrderedStatistic(items_base=frozenset({'oil'}), items_add=frozenset({'newspapers'}), confidence=0.33333333333333337, lift=3.745318352059926)]),
#  RelationRecord(items=frozenset({'root vegetables', 'packaged fruit/vegetables'}), support=0.011, ordered_statistics=[OrderedStatistic(items_base=frozenset({'packaged fruit/vegetables'}), items_add=frozenset({'root vegetables'}), confidence=0.3333333333333333, lift=3.0303030303030303)]),
#  RelationRecord(items=frozenset({'tropical fruit', 'pip fruit'}), support=0.013, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pip fruit'}), items_add=frozenset({'tropical fruit'}), confidence=0.31707317073170727, lift=3.268795574553683)]),
#  RelationRecord(items=frozenset({'sliced cheese', 'yogurt'}), support=0.011, ordered_statistics=[OrderedStatistic(items_base=frozenset({'sliced cheese'}), items_add=frozenset({'yogurt'}), confidence=0.39285714285714285, lift=3.093363329583802)]),
#  RelationRecord(items=frozenset({'whole milk', 'beef', 'root vegetables'}), support=0.01, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whole milk', 'beef'}), items_add=frozenset({'root vegetables'}), confidence=0.3703703703703704, lift=3.367003367003367)]),
#  RelationRecord(items=frozenset({'nan', 'whipped/sour cream', 'berries'}), support=0.017, ordered_statistics=[OrderedStatistic(items_base=frozenset({'berries'}), items_add=frozenset({'nan', 'whipped/sour cream'}), confidence=0.3617021276595745, lift=4.88786658999425), OrderedStatistic(items_base=frozenset({'nan', 'berries'}), items_add=frozenset({'whipped/sour cream'}), confidence=0.3617021276595745, lift=4.88786658999425)]),
#  RelationRecord(items=frozenset({'whole milk', 'root vegetables', 'berries'}), support=0.008, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whole milk', 'berries'}), items_add=frozenset({'root vegetables'}), confidence=0.36363636363636365, lift=3.3057851239669422)]),
#  RelationRecord(items=frozenset({'whole milk', 'whipped/sour cream', 'berries'}), support=0.01, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whole milk', 'berries'}), items_add=frozenset({'whipped/sour cream'}), confidence=0.4545454545454546, lift=6.142506142506144)]),
#  RelationRecord(items=frozenset({'citrus fruit', 'yogurt', 'bottled water'}), support=0.008, ordered_statistics=[OrderedStatistic(items_base=frozenset({'citrus fruit', 'bottled water'}), items_add=frozenset({'yogurt'}), confidence=0.47058823529411764, lift=3.7054191755442334)]),
#  RelationRecord(items=frozenset({'whole milk', 'domestic eggs', 'bottled water'}), support=0.008, ordered_statistics=[OrderedStatistic(items_base=frozenset({'domestic eggs', 'bottled water'}), items_add=frozenset({'whole milk'}), confidence=0.888888888888889, lift=3.304419661296985)]),
#  RelationRecord(items=frozenset({'tropical fruit', 'yogurt', 'bottled water'}), support=0.01, ordered_statistics=[OrderedStatistic(items_base=frozenset({'tropical fruit', 'bottled water'}), items_add=frozenset({'yogurt'}), confidence=0.5555555555555556, lift=4.374453193350831), OrderedStatistic(items_base=frozenset({'yogurt', 'bottled water'}), items_add=frozenset({'tropical fruit'}), confidence=0.33333333333333337, lift=3.436426116838488), OrderedStatistic(items_base=frozenset({'tropical fruit', 'yogurt'}), items_add=frozenset({'bottled water'}), confidence=0.39999999999999997, lift=3.03030303030303)]),
#  RelationRecord(items=frozenset({'nan', 'root vegetables', 'butter'}), support=0.017, ordered_statistics=[OrderedStatistic(items_base=frozenset({'butter'}), items_add=frozenset({'nan', 'root vegetables'}), confidence=0.3695652173913044, lift=3.3596837944664033), OrderedStatistic(items_base=frozenset({'nan', 'butter'}), items_add=frozenset({'root vegetables'}), confidence=0.3695652173913044, lift=3.3596837944664033)]),
#  RelationRecord(items=frozenset({'whole milk', 'root vegetables', 'butter'}), support=0.012, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whole milk', 'butter'}), items_add=frozenset({'root vegetables'}), confidence=0.46153846153846156, lift=4.195804195804196)]),
#  RelationRecord(items=frozenset({'whole milk', 'tropical fruit', 'butter'}), support=0.008, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whole milk', 'butter'}), items_add=frozenset({'tropical fruit'}), confidence=0.3076923076923077, lift=3.1720856463124507)]),
#  RelationRecord(items=frozenset({'whole milk', 'whipped/sour cream', 'butter'}), support=0.008, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whole milk', 'butter'}), items_add=frozenset({'whipped/sour cream'}), confidence=0.3076923076923077, lift=4.158004158004158)]),
#  RelationRecord(items=frozenset({'whole milk', 'yogurt', 'butter'}), support=0.008, ordered_statistics=[OrderedStatistic(items_base=frozenset({'yogurt', 'butter'}), items_add=frozenset({'whole milk'}), confidence=0.888888888888889, lift=3.304419661296985)]),
#  RelationRecord(items=frozenset({'candy', 'nan', 'tropical fruit'}), support=0.009, ordered_statistics=[OrderedStatistic(items_base=frozenset({'candy'}), items_add=frozenset({'nan', 'tropical fruit'}), confidence=0.35999999999999993, lift=3.7113402061855663), OrderedStatistic(items_base=frozenset({'candy', 'nan'}), items_add=frozenset({'tropical fruit'}), confidence=0.35999999999999993, lift=3.7113402061855663)]),
#  RelationRecord(items=frozenset({'coffee', 'nan', 'long life bakery product'}), support=0.008, ordered_statistics=[OrderedStatistic(items_base=frozenset({'long life bakery product'}), items_add=frozenset({'coffee', 'nan'}), confidence=0.3076923076923077, lift=4.048582995951417), OrderedStatistic(items_base=frozenset({'nan', 'long life bakery product'}), items_add=frozenset({'coffee'}), confidence=0.3076923076923077, lift=4.048582995951417)]),
#  RelationRecord(items=frozenset({'curd', 'nan', 'sliced cheese'}), support=0.009, ordered_statistics=[OrderedStatistic(items_base=frozenset({'sliced cheese'}), items_add=frozenset({'curd', 'nan'}), confidence=0.3214285714285714, lift=4.285714285714286), OrderedStatistic(items_base=frozenset({'nan', 'sliced cheese'}), items_add=frozenset({'curd'}), confidence=0.3214285714285714, lift=4.285714285714286)]),
#  RelationRecord(items=frozenset({'curd', 'rolls/buns', 'yogurt'}), support=0.009, ordered_statistics=[OrderedStatistic(items_base=frozenset({'curd', 'rolls/buns'}), items_add=frozenset({'yogurt'}), confidence=0.4285714285714285, lift=3.3745781777277832)]),
#  RelationRecord(items=frozenset({'curd', 'whipped/sour cream', 'yogurt'}), support=0.008, ordered_statistics=[OrderedStatistic(items_base=frozenset({'curd', 'whipped/sour cream'}), items_add=frozenset({'yogurt'}), confidence=0.6153846153846154, lift=4.845548152634767), OrderedStatistic(items_base=frozenset({'curd', 'yogurt'}), items_add=frozenset({'whipped/sour cream'}), confidence=0.3076923076923077, lift=4.158004158004158), OrderedStatistic(items_base=frozenset({'whipped/sour cream', 'yogurt'}), items_add=frozenset({'curd'}), confidence=0.5, lift=6.666666666666667)]),
#  RelationRecord(items=frozenset({'curd', 'whole milk', 'yogurt'}), support=0.016, ordered_statistics=[OrderedStatistic(items_base=frozenset({'curd', 'whole milk'}), items_add=frozenset({'yogurt'}), confidence=0.48484848484848486, lift=3.81770460510618)]),
#  RelationRecord(items=frozenset({'other vegetables', 'tropical fruit', 'fruit/vegetable juice'}), support=0.01, ordered_statistics=[OrderedStatistic(items_base=frozenset({'other vegetables', 'fruit/vegetable juice'}), items_add=frozenset({'tropical fruit'}), confidence=0.47619047619047616, lift=4.909180166912125), OrderedStatistic(items_base=frozenset({'tropical fruit', 'fruit/vegetable juice'}), items_add=frozenset({'other vegetables'}), confidence=0.7142857142857143, lift=3.8402457757296466), OrderedStatistic(items_base=frozenset({'other vegetables', 'tropical fruit'}), items_add=frozenset({'fruit/vegetable juice'}), confidence=0.3125, lift=4.664179104477611)]),
#  RelationRecord(items=frozenset({'other vegetables', 'yogurt', 'fruit/vegetable juice'}), support=0.01, ordered_statistics=[OrderedStatistic(items_base=frozenset({'other vegetables', 'fruit/vegetable juice'}), items_add=frozenset({'yogurt'}), confidence=0.47619047619047616, lift=3.7495313085864264)]),
#  RelationRecord(items=frozenset({'whole milk', 'yogurt', 'fruit/vegetable juice'}), support=0.015, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whole milk', 'fruit/vegetable juice'}), items_add=frozenset({'yogurt'}), confidence=0.5172413793103448, lift=4.072766766223187)]),
#  RelationRecord(items=frozenset({'nan', 'ham', 'whipped/sour cream'}), support=0.008, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ham'}), items_add=frozenset({'nan', 'whipped/sour cream'}), confidence=0.38095238095238093, lift=5.148005148005148), OrderedStatistic(items_base=frozenset({'nan', 'ham'}), items_add=frozenset({'whipped/sour cream'}), confidence=0.38095238095238093, lift=5.148005148005148)]),
#  RelationRecord(items=frozenset({'nan', 'hard cheese', 'tropical fruit'}), support=0.009, ordered_statistics=[OrderedStatistic(items_base=frozenset({'hard cheese'}), items_add=frozenset({'nan', 'tropical fruit'}), confidence=0.37499999999999994, lift=3.865979381443298), OrderedStatistic(items_base=frozenset({'nan', 'hard cheese'}), items_add=frozenset({'tropical fruit'}), confidence=0.37499999999999994, lift=3.865979381443298)]),
#  RelationRecord(items=frozenset({'nan', 'newspapers', 'oil'}), support=0.01, ordered_statistics=[OrderedStatistic(items_base=frozenset({'oil'}), items_add=frozenset({'nan', 'newspapers'}), confidence=0.33333333333333337, lift=3.745318352059926), OrderedStatistic(items_base=frozenset({'nan', 'oil'}), items_add=frozenset({'newspapers'}), confidence=0.33333333333333337, lift=3.745318352059926)]),
#  RelationRecord(items=frozenset({'nan', 'root vegetables', 'packaged fruit/vegetables'}), support=0.011, ordered_statistics=[OrderedStatistic(items_base=frozenset({'packaged fruit/vegetables'}), items_add=frozenset({'nan', 'root vegetables'}), confidence=0.3333333333333333, lift=3.0303030303030303), OrderedStatistic(items_base=frozenset({'nan', 'packaged fruit/vegetables'}), items_add=frozenset({'root vegetables'}), confidence=0.3333333333333333, lift=3.0303030303030303)]),
#  RelationRecord(items=frozenset({'nan', 'tropical fruit', 'pip fruit'}), support=0.013, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pip fruit'}), items_add=frozenset({'nan', 'tropical fruit'}), confidence=0.31707317073170727, lift=3.268795574553683), OrderedStatistic(items_base=frozenset({'nan', 'pip fruit'}), items_add=frozenset({'tropical fruit'}), confidence=0.31707317073170727, lift=3.268795574553683)]),
#  RelationRecord(items=frozenset({'nan', 'sliced cheese', 'yogurt'}), support=0.011, ordered_statistics=[OrderedStatistic(items_base=frozenset({'sliced cheese'}), items_add=frozenset({'nan', 'yogurt'}), confidence=0.39285714285714285, lift=3.093363329583802), OrderedStatistic(items_base=frozenset({'nan', 'sliced cheese'}), items_add=frozenset({'yogurt'}), confidence=0.39285714285714285, lift=3.093363329583802)]),
#  RelationRecord(items=frozenset({'whole milk', 'yogurt', 'napkins'}), support=0.011, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whole milk', 'napkins'}), items_add=frozenset({'yogurt'}), confidence=0.5499999999999999, lift=4.330708661417322)]),
#  RelationRecord(items=frozenset({'other vegetables', 'tropical fruit', 'root vegetables'}), support=0.013, ordered_statistics=[OrderedStatistic(items_base=frozenset({'other vegetables', 'root vegetables'}), items_add=frozenset({'tropical fruit'}), confidence=0.3023255813953489, lift=3.116758571086071), OrderedStatistic(items_base=frozenset({'other vegetables', 'tropical fruit'}), items_add=frozenset({'root vegetables'}), confidence=0.40625, lift=3.6931818181818183)]),
#  RelationRecord(items=frozenset({'other vegetables', 'whipped/sour cream', 'soda'}), support=0.009, ordered_statistics=[OrderedStatistic(items_base=frozenset({'soda', 'whipped/sour cream'}), items_add=frozenset({'other vegetables'}), confidence=0.7499999999999999, lift=4.032258064516128)]),
#  RelationRecord(items=frozenset({'rolls/buns', 'sausage', 'root vegetables'}), support=0.009, ordered_statistics=[OrderedStatistic(items_base=frozenset({'rolls/buns', 'root vegetables'}), items_add=frozenset({'sausage'}), confidence=0.3214285714285714, lift=4.1208791208791204), OrderedStatistic(items_base=frozenset({'sausage', 'root vegetables'}), items_add=frozenset({'rolls/buns'}), confidence=0.6923076923076923, lift=3.1185031185031185)]),
#  RelationRecord(items=frozenset({'whole milk', 'tropical fruit', 'root vegetables'}), support=0.013, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whole milk', 'tropical fruit'}), items_add=frozenset({'root vegetables'}), confidence=0.35135135135135137, lift=3.194103194103194)]),
#  RelationRecord(items=frozenset({'yogurt', 'tropical fruit', 'root vegetables'}), support=0.01, ordered_statistics=[OrderedStatistic(items_base=frozenset({'tropical fruit', 'root vegetables'}), items_add=frozenset({'yogurt'}), confidence=0.38461538461538464, lift=3.0284675953967293), OrderedStatistic(items_base=frozenset({'yogurt', 'root vegetables'}), items_add=frozenset({'tropical fruit'}), confidence=0.38461538461538464, lift=3.965107057890563), OrderedStatistic(items_base=frozenset({'tropical fruit', 'yogurt'}), items_add=frozenset({'root vegetables'}), confidence=0.39999999999999997, lift=3.6363636363636362)]),
#  RelationRecord(items=frozenset({'soda', 'sausage', 'yogurt'}), support=0.008, ordered_statistics=[OrderedStatistic(items_base=frozenset({'soda', 'sausage'}), items_add=frozenset({'yogurt'}), confidence=0.4, lift=3.1496062992125986), OrderedStatistic(items_base=frozenset({'soda', 'yogurt'}), items_add=frozenset({'sausage'}), confidence=0.34782608695652173, lift=4.459308807134894)]),
#  RelationRecord(items=frozenset({'whole milk', 'sausage', 'yogurt'}), support=0.011, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whole milk', 'sausage'}), items_add=frozenset({'yogurt'}), confidence=0.4230769230769231, lift=3.331314354936402)]),
#  RelationRecord(items=frozenset({'whole milk', 'tropical fruit', 'whipped/sour cream'}), support=0.01, ordered_statistics=[OrderedStatistic(items_base=frozenset({'tropical fruit', 'whipped/sour cream'}), items_add=frozenset({'whole milk'}), confidence=0.8333333333333334, lift=3.097893432465923)]),
#  RelationRecord(items=frozenset({'whole milk', 'tropical fruit', 'yogurt'}), support=0.015, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whole milk', 'tropical fruit'}), items_add=frozenset({'yogurt'}), confidence=0.40540540540540543, lift=3.1921685464992553)]),
#  RelationRecord(items=frozenset({'whole milk', 'whipped/sour cream', 'yogurt'}), support=0.013, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whipped/sour cream', 'yogurt'}), items_add=frozenset({'whole milk'}), confidence=0.8125, lift=3.020446096654275)]),
#  RelationRecord(items=frozenset({'nan', 'beef', 'root vegetables', 'whole milk'}), support=0.01, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whole milk', 'beef'}), items_add=frozenset({'nan', 'root vegetables'}), confidence=0.3703703703703704, lift=3.367003367003367), OrderedStatistic(items_base=frozenset({'nan', 'beef', 'whole milk'}), items_add=frozenset({'root vegetables'}), confidence=0.3703703703703704, lift=3.367003367003367)]),
#  RelationRecord(items=frozenset({'nan', 'root vegetables', 'berries', 'whole milk'}), support=0.008, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whole milk', 'berries'}), items_add=frozenset({'nan', 'root vegetables'}), confidence=0.36363636363636365, lift=3.3057851239669422), OrderedStatistic(items_base=frozenset({'nan', 'berries', 'whole milk'}), items_add=frozenset({'root vegetables'}), confidence=0.36363636363636365, lift=3.3057851239669422)]),
#  RelationRecord(items=frozenset({'nan', 'whipped/sour cream', 'berries', 'whole milk'}), support=0.01, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whole milk', 'berries'}), items_add=frozenset({'nan', 'whipped/sour cream'}), confidence=0.4545454545454546, lift=6.142506142506144), OrderedStatistic(items_base=frozenset({'nan', 'berries', 'whole milk'}), items_add=frozenset({'whipped/sour cream'}), confidence=0.4545454545454546, lift=6.142506142506144)]),
#  RelationRecord(items=frozenset({'nan', 'citrus fruit', 'yogurt', 'bottled water'}), support=0.008, ordered_statistics=[OrderedStatistic(items_base=frozenset({'citrus fruit', 'bottled water'}), items_add=frozenset({'nan', 'yogurt'}), confidence=0.47058823529411764, lift=3.7054191755442334), OrderedStatistic(items_base=frozenset({'nan', 'citrus fruit', 'bottled water'}), items_add=frozenset({'yogurt'}), confidence=0.47058823529411764, lift=3.7054191755442334)]),
#  RelationRecord(items=frozenset({'nan', 'whole milk', 'domestic eggs', 'bottled water'}), support=0.008, ordered_statistics=[OrderedStatistic(items_base=frozenset({'domestic eggs', 'bottled water'}), items_add=frozenset({'nan', 'whole milk'}), confidence=0.888888888888889, lift=3.304419661296985), OrderedStatistic(items_base=frozenset({'nan', 'domestic eggs', 'bottled water'}), items_add=frozenset({'whole milk'}), confidence=0.888888888888889, lift=3.304419661296985)]),
#  RelationRecord(items=frozenset({'nan', 'tropical fruit', 'yogurt', 'bottled water'}), support=0.01, ordered_statistics=[OrderedStatistic(items_base=frozenset({'tropical fruit', 'bottled water'}), items_add=frozenset({'nan', 'yogurt'}), confidence=0.5555555555555556, lift=4.374453193350831), OrderedStatistic(items_base=frozenset({'yogurt', 'bottled water'}), items_add=frozenset({'nan', 'tropical fruit'}), confidence=0.33333333333333337, lift=3.436426116838488), OrderedStatistic(items_base=frozenset({'tropical fruit', 'yogurt'}), items_add=frozenset({'nan', 'bottled water'}), confidence=0.39999999999999997, lift=3.03030303030303), OrderedStatistic(items_base=frozenset({'nan', 'tropical fruit', 'bottled water'}), items_add=frozenset({'yogurt'}), confidence=0.5555555555555556, lift=4.374453193350831), OrderedStatistic(items_base=frozenset({'nan', 'yogurt', 'bottled water'}), items_add=frozenset({'tropical fruit'}), confidence=0.33333333333333337, lift=3.436426116838488), OrderedStatistic(items_base=frozenset({'nan', 'tropical fruit', 'yogurt'}), items_add=frozenset({'bottled water'}), confidence=0.39999999999999997, lift=3.03030303030303)]),
#  RelationRecord(items=frozenset({'nan', 'root vegetables', 'butter', 'whole milk'}), support=0.012, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whole milk', 'butter'}), items_add=frozenset({'nan', 'root vegetables'}), confidence=0.46153846153846156, lift=4.195804195804196), OrderedStatistic(items_base=frozenset({'nan', 'butter', 'whole milk'}), items_add=frozenset({'root vegetables'}), confidence=0.46153846153846156, lift=4.195804195804196)]),
#  RelationRecord(items=frozenset({'nan', 'tropical fruit', 'butter', 'whole milk'}), support=0.008, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whole milk', 'butter'}), items_add=frozenset({'nan', 'tropical fruit'}), confidence=0.3076923076923077, lift=3.1720856463124507), OrderedStatistic(items_base=frozenset({'nan', 'butter', 'whole milk'}), items_add=frozenset({'tropical fruit'}), confidence=0.3076923076923077, lift=3.1720856463124507)]),
#  RelationRecord(items=frozenset({'nan', 'whipped/sour cream', 'butter', 'whole milk'}), support=0.008, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whole milk', 'butter'}), items_add=frozenset({'nan', 'whipped/sour cream'}), confidence=0.3076923076923077, lift=4.158004158004158), OrderedStatistic(items_base=frozenset({'nan', 'butter', 'whole milk'}), items_add=frozenset({'whipped/sour cream'}), confidence=0.3076923076923077, lift=4.158004158004158)]),
#  RelationRecord(items=frozenset({'nan', 'yogurt', 'butter', 'whole milk'}), support=0.008, ordered_statistics=[OrderedStatistic(items_base=frozenset({'yogurt', 'butter'}), items_add=frozenset({'nan', 'whole milk'}), confidence=0.888888888888889, lift=3.304419661296985), OrderedStatistic(items_base=frozenset({'nan', 'yogurt', 'butter'}), items_add=frozenset({'whole milk'}), confidence=0.888888888888889, lift=3.304419661296985)]),
#  RelationRecord(items=frozenset({'curd', 'nan', 'rolls/buns', 'yogurt'}), support=0.009, ordered_statistics=[OrderedStatistic(items_base=frozenset({'curd', 'rolls/buns'}), items_add=frozenset({'nan', 'yogurt'}), confidence=0.4285714285714285, lift=3.3745781777277832), OrderedStatistic(items_base=frozenset({'curd', 'nan', 'rolls/buns'}), items_add=frozenset({'yogurt'}), confidence=0.4285714285714285, lift=3.3745781777277832)]),
#  RelationRecord(items=frozenset({'curd', 'nan', 'whipped/sour cream', 'yogurt'}), support=0.008, ordered_statistics=[OrderedStatistic(items_base=frozenset({'curd', 'whipped/sour cream'}), items_add=frozenset({'nan', 'yogurt'}), confidence=0.6153846153846154, lift=4.845548152634767), OrderedStatistic(items_base=frozenset({'curd', 'yogurt'}), items_add=frozenset({'nan', 'whipped/sour cream'}), confidence=0.3076923076923077, lift=4.158004158004158), OrderedStatistic(items_base=frozenset({'whipped/sour cream', 'yogurt'}), items_add=frozenset({'curd', 'nan'}), confidence=0.5, lift=6.666666666666667), OrderedStatistic(items_base=frozenset({'curd', 'nan', 'whipped/sour cream'}), items_add=frozenset({'yogurt'}), confidence=0.6153846153846154, lift=4.845548152634767), OrderedStatistic(items_base=frozenset({'curd', 'nan', 'yogurt'}), items_add=frozenset({'whipped/sour cream'}), confidence=0.3076923076923077, lift=4.158004158004158), OrderedStatistic(items_base=frozenset({'nan', 'whipped/sour cream', 'yogurt'}), items_add=frozenset({'curd'}), confidence=0.5, lift=6.666666666666667)]),
#  RelationRecord(items=frozenset({'curd', 'nan', 'yogurt', 'whole milk'}), support=0.016, ordered_statistics=[OrderedStatistic(items_base=frozenset({'curd', 'whole milk'}), items_add=frozenset({'nan', 'yogurt'}), confidence=0.48484848484848486, lift=3.81770460510618), OrderedStatistic(items_base=frozenset({'curd', 'nan', 'whole milk'}), items_add=frozenset({'yogurt'}), confidence=0.48484848484848486, lift=3.81770460510618)]),
#  RelationRecord(items=frozenset({'nan', 'tropical fruit', 'other vegetables', 'fruit/vegetable juice'}), support=0.01, ordered_statistics=[OrderedStatistic(items_base=frozenset({'other vegetables', 'fruit/vegetable juice'}), items_add=frozenset({'nan', 'tropical fruit'}), confidence=0.47619047619047616, lift=4.909180166912125), OrderedStatistic(items_base=frozenset({'tropical fruit', 'fruit/vegetable juice'}), items_add=frozenset({'nan', 'other vegetables'}), confidence=0.7142857142857143, lift=3.8402457757296466), OrderedStatistic(items_base=frozenset({'other vegetables', 'tropical fruit'}), items_add=frozenset({'nan', 'fruit/vegetable juice'}), confidence=0.3125, lift=4.664179104477611), OrderedStatistic(items_base=frozenset({'nan', 'other vegetables', 'fruit/vegetable juice'}), items_add=frozenset({'tropical fruit'}), confidence=0.47619047619047616, lift=4.909180166912125), OrderedStatistic(items_base=frozenset({'nan', 'tropical fruit', 'fruit/vegetable juice'}), items_add=frozenset({'other vegetables'}), confidence=0.7142857142857143, lift=3.8402457757296466), OrderedStatistic(items_base=frozenset({'nan', 'tropical fruit', 'other vegetables'}), items_add=frozenset({'fruit/vegetable juice'}), confidence=0.3125, lift=4.664179104477611)]),
#  RelationRecord(items=frozenset({'nan', 'yogurt', 'other vegetables', 'fruit/vegetable juice'}), support=0.01, ordered_statistics=[OrderedStatistic(items_base=frozenset({'other vegetables', 'fruit/vegetable juice'}), items_add=frozenset({'nan', 'yogurt'}), confidence=0.47619047619047616, lift=3.7495313085864264), OrderedStatistic(items_base=frozenset({'nan', 'other vegetables', 'fruit/vegetable juice'}), items_add=frozenset({'yogurt'}), confidence=0.47619047619047616, lift=3.7495313085864264)]),
#  RelationRecord(items=frozenset({'nan', 'whole milk', 'yogurt', 'fruit/vegetable juice'}), support=0.015, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whole milk', 'fruit/vegetable juice'}), items_add=frozenset({'nan', 'yogurt'}), confidence=0.5172413793103448, lift=4.072766766223187), OrderedStatistic(items_base=frozenset({'nan', 'whole milk', 'fruit/vegetable juice'}), items_add=frozenset({'yogurt'}), confidence=0.5172413793103448, lift=4.072766766223187)]),
#  RelationRecord(items=frozenset({'other vegetables', 'whole milk', 'yogurt', 'fruit/vegetable juice'}), support=0.009, ordered_statistics=[OrderedStatistic(items_base=frozenset({'other vegetables', 'fruit/vegetable juice'}), items_add=frozenset({'whole milk', 'yogurt'}), confidence=0.4285714285714285, lift=7.653061224489794), OrderedStatistic(items_base=frozenset({'whole milk', 'fruit/vegetable juice'}), items_add=frozenset({'other vegetables', 'yogurt'}), confidence=0.31034482758620685, lift=8.866995073891623), OrderedStatistic(items_base=frozenset({'yogurt', 'fruit/vegetable juice'}), items_add=frozenset({'other vegetables', 'whole milk'}), confidence=0.47368421052631576, lift=6.578947368421053), OrderedStatistic(items_base=frozenset({'other vegetables', 'whole milk', 'fruit/vegetable juice'}), items_add=frozenset({'yogurt'}), confidence=0.7499999999999999, lift=5.905511811023621), OrderedStatistic(items_base=frozenset({'other vegetables', 'yogurt', 'fruit/vegetable juice'}), items_add=frozenset({'whole milk'}), confidence=0.8999999999999999, lift=3.3457249070631967), OrderedStatistic(items_base=frozenset({'whole milk', 'yogurt', 'fruit/vegetable juice'}), items_add=frozenset({'other vegetables'}), confidence=0.6, lift=3.225806451612903), OrderedStatistic(items_base=frozenset({'other vegetables', 'yogurt', 'whole milk'}), items_add=frozenset({'fruit/vegetable juice'}), confidence=0.47368421052631576, lift=7.069913589945011)]),
#  RelationRecord(items=frozenset({'nan', 'yogurt', 'napkins', 'whole milk'}), support=0.011, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whole milk', 'napkins'}), items_add=frozenset({'nan', 'yogurt'}), confidence=0.5499999999999999, lift=4.330708661417322), OrderedStatistic(items_base=frozenset({'nan', 'napkins', 'whole milk'}), items_add=frozenset({'yogurt'}), confidence=0.5499999999999999, lift=4.330708661417322)]),
#  RelationRecord(items=frozenset({'nan', 'tropical fruit', 'root vegetables', 'other vegetables'}), support=0.013, ordered_statistics=[OrderedStatistic(items_base=frozenset({'other vegetables', 'root vegetables'}), items_add=frozenset({'nan', 'tropical fruit'}), confidence=0.3023255813953489, lift=3.116758571086071), OrderedStatistic(items_base=frozenset({'other vegetables', 'tropical fruit'}), items_add=frozenset({'nan', 'root vegetables'}), confidence=0.40625, lift=3.6931818181818183), OrderedStatistic(items_base=frozenset({'nan', 'root vegetables', 'other vegetables'}), items_add=frozenset({'tropical fruit'}), confidence=0.3023255813953489, lift=3.116758571086071), OrderedStatistic(items_base=frozenset({'nan', 'tropical fruit', 'other vegetables'}), items_add=frozenset({'root vegetables'}), confidence=0.40625, lift=3.6931818181818183)]),
#  RelationRecord(items=frozenset({'nan', 'whipped/sour cream', 'other vegetables', 'soda'}), support=0.009, ordered_statistics=[OrderedStatistic(items_base=frozenset({'soda', 'whipped/sour cream'}), items_add=frozenset({'nan', 'other vegetables'}), confidence=0.7499999999999999, lift=4.032258064516128), OrderedStatistic(items_base=frozenset({'nan', 'whipped/sour cream', 'soda'}), items_add=frozenset({'other vegetables'}), confidence=0.7499999999999999, lift=4.032258064516128)]),
#  RelationRecord(items=frozenset({'nan', 'rolls/buns', 'sausage', 'root vegetables'}), support=0.009, ordered_statistics=[OrderedStatistic(items_base=frozenset({'rolls/buns', 'root vegetables'}), items_add=frozenset({'nan', 'sausage'}), confidence=0.3214285714285714, lift=4.1208791208791204), OrderedStatistic(items_base=frozenset({'sausage', 'root vegetables'}), items_add=frozenset({'nan', 'rolls/buns'}), confidence=0.6923076923076923, lift=3.1185031185031185), OrderedStatistic(items_base=frozenset({'nan', 'rolls/buns', 'root vegetables'}), items_add=frozenset({'sausage'}), confidence=0.3214285714285714, lift=4.1208791208791204), OrderedStatistic(items_base=frozenset({'nan', 'sausage', 'root vegetables'}), items_add=frozenset({'rolls/buns'}), confidence=0.6923076923076923, lift=3.1185031185031185)]),
#  RelationRecord(items=frozenset({'nan', 'tropical fruit', 'root vegetables', 'whole milk'}), support=0.013, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whole milk', 'tropical fruit'}), items_add=frozenset({'nan', 'root vegetables'}), confidence=0.35135135135135137, lift=3.194103194103194), OrderedStatistic(items_base=frozenset({'nan', 'tropical fruit', 'whole milk'}), items_add=frozenset({'root vegetables'}), confidence=0.35135135135135137, lift=3.194103194103194)]),
#  RelationRecord(items=frozenset({'yogurt', 'nan', 'tropical fruit', 'root vegetables'}), support=0.01, ordered_statistics=[OrderedStatistic(items_base=frozenset({'tropical fruit', 'root vegetables'}), items_add=frozenset({'nan', 'yogurt'}), confidence=0.38461538461538464, lift=3.0284675953967293), OrderedStatistic(items_base=frozenset({'yogurt', 'root vegetables'}), items_add=frozenset({'nan', 'tropical fruit'}), confidence=0.38461538461538464, lift=3.965107057890563), OrderedStatistic(items_base=frozenset({'tropical fruit', 'yogurt'}), items_add=frozenset({'nan', 'root vegetables'}), confidence=0.39999999999999997, lift=3.6363636363636362), OrderedStatistic(items_base=frozenset({'nan', 'tropical fruit', 'root vegetables'}), items_add=frozenset({'yogurt'}), confidence=0.38461538461538464, lift=3.0284675953967293), OrderedStatistic(items_base=frozenset({'nan', 'yogurt', 'root vegetables'}), items_add=frozenset({'tropical fruit'}), confidence=0.38461538461538464, lift=3.965107057890563), OrderedStatistic(items_base=frozenset({'nan', 'tropical fruit', 'yogurt'}), items_add=frozenset({'root vegetables'}), confidence=0.39999999999999997, lift=3.6363636363636362)]),
#  RelationRecord(items=frozenset({'nan', 'sausage', 'yogurt', 'soda'}), support=0.008, ordered_statistics=[OrderedStatistic(items_base=frozenset({'soda', 'sausage'}), items_add=frozenset({'nan', 'yogurt'}), confidence=0.4, lift=3.1496062992125986), OrderedStatistic(items_base=frozenset({'soda', 'yogurt'}), items_add=frozenset({'nan', 'sausage'}), confidence=0.34782608695652173, lift=4.459308807134894), OrderedStatistic(items_base=frozenset({'nan', 'sausage', 'soda'}), items_add=frozenset({'yogurt'}), confidence=0.4, lift=3.1496062992125986), OrderedStatistic(items_base=frozenset({'nan', 'yogurt', 'soda'}), items_add=frozenset({'sausage'}), confidence=0.34782608695652173, lift=4.459308807134894)]),
#  RelationRecord(items=frozenset({'nan', 'sausage', 'yogurt', 'whole milk'}), support=0.011, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whole milk', 'sausage'}), items_add=frozenset({'nan', 'yogurt'}), confidence=0.4230769230769231, lift=3.331314354936402), OrderedStatistic(items_base=frozenset({'nan', 'sausage', 'whole milk'}), items_add=frozenset({'yogurt'}), confidence=0.4230769230769231, lift=3.331314354936402)]),
#  RelationRecord(items=frozenset({'nan', 'tropical fruit', 'whipped/sour cream', 'whole milk'}), support=0.01, ordered_statistics=[OrderedStatistic(items_base=frozenset({'tropical fruit', 'whipped/sour cream'}), items_add=frozenset({'nan', 'whole milk'}), confidence=0.8333333333333334, lift=3.097893432465923), OrderedStatistic(items_base=frozenset({'nan', 'tropical fruit', 'whipped/sour cream'}), items_add=frozenset({'whole milk'}), confidence=0.8333333333333334, lift=3.097893432465923)]),
#  RelationRecord(items=frozenset({'nan', 'tropical fruit', 'yogurt', 'whole milk'}), support=0.015, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whole milk', 'tropical fruit'}), items_add=frozenset({'nan', 'yogurt'}), confidence=0.40540540540540543, lift=3.1921685464992553), OrderedStatistic(items_base=frozenset({'nan', 'tropical fruit', 'whole milk'}), items_add=frozenset({'yogurt'}), confidence=0.40540540540540543, lift=3.1921685464992553)]),
#  RelationRecord(items=frozenset({'nan', 'whipped/sour cream', 'yogurt', 'whole milk'}), support=0.013, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whipped/sour cream', 'yogurt'}), items_add=frozenset({'nan', 'whole milk'}), confidence=0.8125, lift=3.020446096654275), OrderedStatistic(items_base=frozenset({'nan', 'whipped/sour cream', 'yogurt'}), items_add=frozenset({'whole milk'}), confidence=0.8125, lift=3.020446096654275)]),
#  RelationRecord(items=frozenset({'nan', 'fruit/vegetable juice', 'whole milk', 'other vegetables', 'yogurt'}), support=0.009, ordered_statistics=[OrderedStatistic(items_base=frozenset({'other vegetables', 'fruit/vegetable juice'}), items_add=frozenset({'nan', 'yogurt', 'whole milk'}), confidence=0.4285714285714285, lift=7.653061224489794), OrderedStatistic(items_base=frozenset({'whole milk', 'fruit/vegetable juice'}), items_add=frozenset({'nan', 'yogurt', 'other vegetables'}), confidence=0.31034482758620685, lift=8.866995073891623), OrderedStatistic(items_base=frozenset({'yogurt', 'fruit/vegetable juice'}), items_add=frozenset({'nan', 'other vegetables', 'whole milk'}), confidence=0.47368421052631576, lift=6.578947368421053), OrderedStatistic(items_base=frozenset({'nan', 'other vegetables', 'fruit/vegetable juice'}), items_add=frozenset({'whole milk', 'yogurt'}), confidence=0.4285714285714285, lift=7.653061224489794), OrderedStatistic(items_base=frozenset({'nan', 'whole milk', 'fruit/vegetable juice'}), items_add=frozenset({'other vegetables', 'yogurt'}), confidence=0.31034482758620685, lift=8.866995073891623), OrderedStatistic(items_base=frozenset({'nan', 'yogurt', 'fruit/vegetable juice'}), items_add=frozenset({'whole milk', 'other vegetables'}), confidence=0.47368421052631576, lift=6.578947368421053), OrderedStatistic(items_base=frozenset({'other vegetables', 'whole milk', 'fruit/vegetable juice'}), items_add=frozenset({'nan', 'yogurt'}), confidence=0.7499999999999999, lift=5.905511811023621), OrderedStatistic(items_base=frozenset({'other vegetables', 'yogurt', 'fruit/vegetable juice'}), items_add=frozenset({'nan', 'whole milk'}), confidence=0.8999999999999999, lift=3.3457249070631967), OrderedStatistic(items_base=frozenset({'whole milk', 'yogurt', 'fruit/vegetable juice'}), items_add=frozenset({'nan', 'other vegetables'}), confidence=0.6, lift=3.225806451612903), OrderedStatistic(items_base=frozenset({'other vegetables', 'yogurt', 'whole milk'}), items_add=frozenset({'nan', 'fruit/vegetable juice'}), confidence=0.47368421052631576, lift=7.069913589945011), OrderedStatistic(items_base=frozenset({'nan', 'whole milk', 'other vegetables', 'fruit/vegetable juice'}), items_add=frozenset({'yogurt'}), confidence=0.7499999999999999, lift=5.905511811023621), OrderedStatistic(items_base=frozenset({'nan', 'yogurt', 'other vegetables', 'fruit/vegetable juice'}), items_add=frozenset({'whole milk'}), confidence=0.8999999999999999, lift=3.3457249070631967), OrderedStatistic(items_base=frozenset({'nan', 'whole milk', 'yogurt', 'fruit/vegetable juice'}), items_add=frozenset({'other vegetables'}), confidence=0.6, lift=3.225806451612903), OrderedStatistic(items_base=frozenset({'nan', 'yogurt', 'other vegetables', 'whole milk'}), items_add=frozenset({'fruit/vegetable juice'}), confidence=0.47368421052631576, lift=7.069913589945011)])]

# %%
for item in association_results:
    pair = item[0] 
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])
    print("Support: " + str(item[1]))
    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("==========================================")
# Out:
# Rule: whipped/sour cream -> berries
# Support: 0.017
# Confidence: 0.3617021276595745
# Lift: 4.88786658999425
# ==========================================
# Rule: root vegetables -> butter
# Support: 0.017
# Confidence: 0.3695652173913044
# Lift: 3.3596837944664033
# ==========================================
# Rule: candy -> tropical fruit
# Support: 0.009
# Confidence: 0.35999999999999993
# Lift: 3.7113402061855663
# ==========================================
# Rule: coffee -> long life bakery product
# Support: 0.008
# Confidence: 0.3076923076923077
# Lift: 4.048582995951417
# ==========================================
# Rule: curd -> sliced cheese
# Support: 0.009
# Confidence: 0.3214285714285714
# Lift: 4.285714285714286
# ==========================================
# Rule: ham -> whipped/sour cream
# Support: 0.008
# Confidence: 0.38095238095238093
# Lift: 5.148005148005148
# ==========================================
# Rule: hard cheese -> tropical fruit
# Support: 0.009
# Confidence: 0.37499999999999994
# Lift: 3.865979381443298
# ==========================================
# Rule: newspapers -> oil
# Support: 0.01
# Confidence: 0.33333333333333337
# Lift: 3.745318352059926
# ==========================================
# Rule: root vegetables -> packaged fruit/vegetables
# Support: 0.011
# Confidence: 0.3333333333333333
# Lift: 3.0303030303030303
# ==========================================
# Rule: tropical fruit -> pip fruit
# Support: 0.013
# Confidence: 0.31707317073170727
# Lift: 3.268795574553683
# ==========================================
# Rule: sliced cheese -> yogurt
# Support: 0.011
# Confidence: 0.39285714285714285
# Lift: 3.093363329583802
# ==========================================
# Rule: whole milk -> beef
# Support: 0.01
# Confidence: 0.3703703703703704
# Lift: 3.367003367003367
# ==========================================
# Rule: nan -> whipped/sour cream
# Support: 0.017
# Confidence: 0.3617021276595745
# Lift: 4.88786658999425
# ==========================================
# Rule: whole milk -> root vegetables
# Support: 0.008
# Confidence: 0.36363636363636365
# Lift: 3.3057851239669422
# ==========================================
# Rule: whole milk -> whipped/sour cream
# Support: 0.01
# Confidence: 0.4545454545454546
# Lift: 6.142506142506144
# ==========================================
# Rule: citrus fruit -> yogurt
# Support: 0.008
# Confidence: 0.47058823529411764
# Lift: 3.7054191755442334
# ==========================================
# Rule: whole milk -> domestic eggs
# Support: 0.008
# Confidence: 0.888888888888889
# Lift: 3.304419661296985
# ==========================================
# Rule: tropical fruit -> yogurt
# Support: 0.01
# Confidence: 0.5555555555555556
# Lift: 4.374453193350831
# ==========================================
# Rule: nan -> root vegetables
# Support: 0.017
# Confidence: 0.3695652173913044
# Lift: 3.3596837944664033
# ==========================================
# Rule: whole milk -> root vegetables
# Support: 0.012
# Confidence: 0.46153846153846156
# Lift: 4.195804195804196
# ==========================================
# Rule: whole milk -> tropical fruit
# Support: 0.008
# Confidence: 0.3076923076923077
# Lift: 3.1720856463124507
# ==========================================
# Rule: whole milk -> whipped/sour cream
# Support: 0.008
# Confidence: 0.3076923076923077
# Lift: 4.158004158004158
# ==========================================
# Rule: whole milk -> yogurt
# Support: 0.008
# Confidence: 0.888888888888889
# Lift: 3.304419661296985
# ==========================================
# Rule: candy -> nan
# Support: 0.009
# Confidence: 0.35999999999999993
# Lift: 3.7113402061855663
# ==========================================
# Rule: coffee -> nan
# Support: 0.008
# Confidence: 0.3076923076923077
# Lift: 4.048582995951417
# ==========================================
# Rule: curd -> nan
# Support: 0.009
# Confidence: 0.3214285714285714
# Lift: 4.285714285714286
# ==========================================
# Rule: curd -> rolls/buns
# Support: 0.009
# Confidence: 0.4285714285714285
# Lift: 3.3745781777277832
# ==========================================
# Rule: curd -> whipped/sour cream
# Support: 0.008
# Confidence: 0.6153846153846154
# Lift: 4.845548152634767
# ==========================================
# Rule: curd -> whole milk
# Support: 0.016
# Confidence: 0.48484848484848486
# Lift: 3.81770460510618
# ==========================================
# Rule: other vegetables -> tropical fruit
# Support: 0.01
# Confidence: 0.47619047619047616
# Lift: 4.909180166912125
# ==========================================
# Rule: other vegetables -> yogurt
# Support: 0.01
# Confidence: 0.47619047619047616
# Lift: 3.7495313085864264
# ==========================================
# Rule: whole milk -> yogurt
# Support: 0.015
# Confidence: 0.5172413793103448
# Lift: 4.072766766223187
# ==========================================
# Rule: nan -> ham
# Support: 0.008
# Confidence: 0.38095238095238093
# Lift: 5.148005148005148
# ==========================================
# Rule: nan -> hard cheese
# Support: 0.009
# Confidence: 0.37499999999999994
# Lift: 3.865979381443298
# ==========================================
# Rule: nan -> newspapers
# Support: 0.01
# Confidence: 0.33333333333333337
# Lift: 3.745318352059926
# ==========================================
# Rule: nan -> root vegetables
# Support: 0.011
# Confidence: 0.3333333333333333
# Lift: 3.0303030303030303
# ==========================================
# Rule: nan -> tropical fruit
# Support: 0.013
# Confidence: 0.31707317073170727
# Lift: 3.268795574553683
# ==========================================
# Rule: nan -> sliced cheese
# Support: 0.011
# Confidence: 0.39285714285714285
# Lift: 3.093363329583802
# ==========================================
# Rule: whole milk -> yogurt
# Support: 0.011
# Confidence: 0.5499999999999999
# Lift: 4.330708661417322
# ==========================================
# Rule: other vegetables -> tropical fruit
# Support: 0.013
# Confidence: 0.3023255813953489
# Lift: 3.116758571086071
# ==========================================
# Rule: other vegetables -> whipped/sour cream
# Support: 0.009
# Confidence: 0.7499999999999999
# Lift: 4.032258064516128
# ==========================================
# Rule: rolls/buns -> sausage
# Support: 0.009
# Confidence: 0.3214285714285714
# Lift: 4.1208791208791204
# ==========================================
# Rule: whole milk -> tropical fruit
# Support: 0.013
# Confidence: 0.35135135135135137
# Lift: 3.194103194103194
# ==========================================
# Rule: yogurt -> tropical fruit
# Support: 0.01
# Confidence: 0.38461538461538464
# Lift: 3.0284675953967293
# ==========================================
# Rule: soda -> sausage
# Support: 0.008
# Confidence: 0.4
# Lift: 3.1496062992125986
# ==========================================
# Rule: whole milk -> sausage
# Support: 0.011
# Confidence: 0.4230769230769231
# Lift: 3.331314354936402
# ==========================================
# Rule: whole milk -> tropical fruit
# Support: 0.01
# Confidence: 0.8333333333333334
# Lift: 3.097893432465923
# ==========================================
# Rule: whole milk -> tropical fruit
# Support: 0.015
# Confidence: 0.40540540540540543
# Lift: 3.1921685464992553
# ==========================================
# Rule: whole milk -> whipped/sour cream
# Support: 0.013
# Confidence: 0.8125
# Lift: 3.020446096654275
# ==========================================
# Rule: nan -> beef
# Support: 0.01
# Confidence: 0.3703703703703704
# Lift: 3.367003367003367
# ==========================================
# Rule: nan -> root vegetables
# Support: 0.008
# Confidence: 0.36363636363636365
# Lift: 3.3057851239669422
# ==========================================
# Rule: nan -> whipped/sour cream
# Support: 0.01
# Confidence: 0.4545454545454546
# Lift: 6.142506142506144
# ==========================================
# Rule: nan -> citrus fruit
# Support: 0.008
# Confidence: 0.47058823529411764
# Lift: 3.7054191755442334
# ==========================================
# Rule: nan -> whole milk
# Support: 0.008
# Confidence: 0.888888888888889
# Lift: 3.304419661296985
# ==========================================
# Rule: nan -> tropical fruit
# Support: 0.01
# Confidence: 0.5555555555555556
# Lift: 4.374453193350831
# ==========================================
# Rule: nan -> root vegetables
# Support: 0.012
# Confidence: 0.46153846153846156
# Lift: 4.195804195804196
# ==========================================
# Rule: nan -> tropical fruit
# Support: 0.008
# Confidence: 0.3076923076923077
# Lift: 3.1720856463124507
# ==========================================
# Rule: nan -> whipped/sour cream
# Support: 0.008
# Confidence: 0.3076923076923077
# Lift: 4.158004158004158
# ==========================================
# Rule: nan -> yogurt
# Support: 0.008
# Confidence: 0.888888888888889
# Lift: 3.304419661296985
# ==========================================
# Rule: curd -> nan
# Support: 0.009
# Confidence: 0.4285714285714285
# Lift: 3.3745781777277832
# ==========================================
# Rule: curd -> nan
# Support: 0.008
# Confidence: 0.6153846153846154
# Lift: 4.845548152634767
# ==========================================
# Rule: curd -> nan
# Support: 0.016
# Confidence: 0.48484848484848486
# Lift: 3.81770460510618
# ==========================================
# Rule: nan -> tropical fruit
# Support: 0.01
# Confidence: 0.47619047619047616
# Lift: 4.909180166912125
# ==========================================
# Rule: nan -> yogurt
# Support: 0.01
# Confidence: 0.47619047619047616
# Lift: 3.7495313085864264
# ==========================================
# Rule: nan -> whole milk
# Support: 0.015
# Confidence: 0.5172413793103448
# Lift: 4.072766766223187
# ==========================================
# Rule: other vegetables -> whole milk
# Support: 0.009
# Confidence: 0.4285714285714285
# Lift: 7.653061224489794
# ==========================================
# Rule: nan -> yogurt
# Support: 0.011
# Confidence: 0.5499999999999999
# Lift: 4.330708661417322
# ==========================================
# Rule: nan -> tropical fruit
# Support: 0.013
# Confidence: 0.3023255813953489
# Lift: 3.116758571086071
# ==========================================
# Rule: nan -> whipped/sour cream
# Support: 0.009
# Confidence: 0.7499999999999999
# Lift: 4.032258064516128
# ==========================================
# Rule: nan -> rolls/buns
# Support: 0.009
# Confidence: 0.3214285714285714
# Lift: 4.1208791208791204
# ==========================================
# Rule: nan -> tropical fruit
# Support: 0.013
# Confidence: 0.35135135135135137
# Lift: 3.194103194103194
# ==========================================
# Rule: yogurt -> nan
# Support: 0.01
# Confidence: 0.38461538461538464
# Lift: 3.0284675953967293
# ==========================================
# Rule: nan -> sausage
# Support: 0.008
# Confidence: 0.4
# Lift: 3.1496062992125986
# ==========================================
# Rule: nan -> sausage
# Support: 0.011
# Confidence: 0.4230769230769231
# Lift: 3.331314354936402
# ==========================================
# Rule: nan -> tropical fruit
# Support: 0.01
# Confidence: 0.8333333333333334
# Lift: 3.097893432465923
# ==========================================
# Rule: nan -> tropical fruit
# Support: 0.015
# Confidence: 0.40540540540540543
# Lift: 3.1921685464992553
# ==========================================
# Rule: nan -> whipped/sour cream
# Support: 0.013
# Confidence: 0.8125
# Lift: 3.020446096654275
# ==========================================
# Rule: nan -> fruit/vegetable juice
# Support: 0.009
# Confidence: 0.4285714285714285
# Lift: 7.653061224489794
# ==========================================
